# %% [markdown]
# # Experiment V1: YOLOv8 Baseline for Object Detection
#
# **Student ID:** 25509225
# **Experiment:** V1 - YOLOv8 Baseline (Standard Model)
# **Model:** YOLOv8m (no customization)
#
# ---
#
# ## Overview
#
# This experiment trains a standard YOLOv8m model on the dog emotion detection dataset without any architectural modifications. This serves as the baseline for comparison with customized models (V2: Deeper Backbone, V3: Shallower Backbone).

# %% [markdown]
# ## Cell 1: Load Modules

# %%
# Load shared modules from YOLOv8_modules.ipynb
# %run ./YOLOv8_modules.ipynb

print("✓ All modules loaded successfully")
# Out:
# ✓ ultralytics already installed
#
# Using device: cuda
# GPU: Tesla T4
# Memory: 14.6 GB
#
# Package Versions:
#   PyTorch: 2.6.0
#   Ultralytics: 8.4.48
#   OpenCV: 4.13.0
#   NumPy: 2.4.4
# ✓ YOLOv8Detector defined
# ✓ Model configurations defined
# ✓ YOLOv8Trainer defined
# ✓ Training configurations defined
# ✓ DetectionEvaluator defined
#
# ✓ All YOLOv8 modules loaded successfully!
# ✓ All modules loaded successfully

# %% [markdown]
# ## Cell 2: Configuration

# %%
# ============================================================================
# Experiment V1: YOLOv8 Baseline Configuration
# ============================================================================

# === Model Configuration ===
YOLOV8_V1_MODEL_CONFIG = {
    'backbone': 'm',
    'input_size': 640,
    'confidence_threshold': 0.5,
    'nms_iou_threshold': 0.45,
    'pretrained': True,
    'customize_type': None          # Baseline - no customization
}

# === Training Configuration ===
TRAINING_CONFIG_V1 = {
    'learning_rate': 0.0005,
    'batch_size': 12,        
    'epochs': 300,
    'optimizer': 'adam',
    'weight_decay': 5e-4,
    'use_amp': True,                # Mixed precision (already enabled)
    'patience': 30                  # Early stopping patience
}

# === Experiment Settings ===
STUDENT_ID = "25509225"
DATASET_CONFIG = f"/home/sagemaker-user/CNN_A2/data/{STUDENT_ID}/Object_Detection/yolo/data.yaml"
USE_PRETRAINED = True

# Output directory (simplified, no timestamp subdirectory)
output_dir = Path('/home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1')
output_dir.mkdir(parents=True, exist_ok=True)

# Print experiment info
print("=" * 80)
print("EXPERIMENT V1: YOLOv8 Baseline")
print("=" * 80)
print(f"\nExperiment Settings:")
print(f"  Student ID: {STUDENT_ID}")
print(f"  Dataset Config: {DATASET_CONFIG}")
print(f"  Output Directory: {output_dir}")
print(f"\nModel Configuration:")
print(f"  Backbone: YOLOv8{YOLOV8_V1_MODEL_CONFIG['backbone']}")
print(f"  Input Size: {YOLOV8_V1_MODEL_CONFIG['input_size']}")
print(f"  Pretrained: {USE_PRETRAINED}")
print(f"  Customization: None (Baseline)")
print(f"\nTraining Configuration:")
print(f"  Learning Rate: {TRAINING_CONFIG_V1['learning_rate']}")
print(f"  Batch Size: {TRAINING_CONFIG_V1['batch_size']}")
print(f"  Epochs: {TRAINING_CONFIG_V1['epochs']}")
print(f"  Optimizer: {TRAINING_CONFIG_V1['optimizer']}")
print(f"  Weight Decay: {TRAINING_CONFIG_V1['weight_decay']}")
print(f"  Mixed Precision: {TRAINING_CONFIG_V1['use_amp']}")
print(f"  Early Stopping: {TRAINING_CONFIG_V1['patience']} epochs")
# Out:
# ================================================================================
# EXPERIMENT V1: YOLOv8 Baseline
# ================================================================================
#
# Experiment Settings:
#   Student ID: 25509225
#   Dataset Config: /home/sagemaker-user/CNN_A2/data/25509225/Object_Detection/yolo/data.yaml
#   Output Directory: /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1
#
# Model Configuration:
#   Backbone: YOLOv8m
#   Input Size: 640
#   Pretrained: True
#   Customization: None (Baseline)
#
# Training Configuration:
#   Learning Rate: 0.0005
#   Batch Size: 12
#   Epochs: 300
#   Optimizer: adam
#   Weight Decay: 0.0005
#   Mixed Precision: True
#   Early Stopping: 30 epochs

# %% [markdown]
# ## Cell 3: Step 1 - Load Dataset Configuration

# %%
# ============================================================================
# Step 1: Load Dataset Configuration
# ============================================================================

print("\n[1/5] Loading dataset configuration...")
print("=" * 80)

dataset_config_path = Path(DATASET_CONFIG)

if not dataset_config_path.exists():
    print(f"Error: Dataset config not found: {dataset_config_path}")
    print("Please check the DATASET_CONFIG path in Cell 2")
    raise FileNotFoundError(f"Dataset config not found: {dataset_config_path}")

with open(dataset_config_path, 'r') as f:
    dataset_config = yaml.safe_load(f)

print(f"Dataset config: {dataset_config_path}")
print(f"Number of classes: {dataset_config['nc']}")
print(f"Class names: {dataset_config['names']}")
print(f"\nPaths:")
print(f"  Train: {dataset_config.get('train', 'N/A')}")
print(f"  Val: {dataset_config.get('val', 'N/A')}")
print(f"  Test: {dataset_config.get('test', 'N/A')}")
print("\n✓ Dataset configuration loaded successfully")
# Out:
# [1/5] Loading dataset configuration...
# ================================================================================
# Dataset config: /home/sagemaker-user/CNN_A2/data/25509225/Object_Detection/yolo/data.yaml
# Number of classes: 5
# Class names: ['Cell', 'Cell-Multi', 'No-Anomaly', 'Shadowing', 'Unclassified']
#
# Paths:
#   Train: ../train/images
#   Val: ../valid/images
#   Test: ../test/images
#
# ✓ Dataset configuration loaded successfully

# %% [markdown]
# ## Cell 4: Step 2 - Initialize Model

# %%
# ============================================================================
# Step 2: Initialize YOLOv8 Model
# ============================================================================

print("\n[2/5] Initializing YOLOv8 model...")
print("=" * 80)

# Update model config with the pretrained setting
model_config = YOLOV8_V1_MODEL_CONFIG.copy()
model_config['pretrained'] = USE_PRETRAINED

# Create model
model = YOLOv8Detector(**model_config)

print(f"\nModel Information:")
print(f"  Model: Standard YOLOv8{model_config['backbone']}")
print(f"  Input Size: {model_config['input_size']}")
print(f"  Pretrained: {USE_PRETRAINED}")
print(f"  Customization: None (Baseline)")
print(f"  Confidence Threshold: {model_config['confidence_threshold']}")
print(f"  NMS IoU Threshold: {model_config['nms_iou_threshold']}")

# Calculate approximate parameters
total_params = sum(p.numel() for p in model.model.parameters())
print(f"\n  Total Parameters: ~{total_params/1e6:.1f}M")
print("\n✓ Model initialized successfully")
# Out:
# [2/5] Initializing YOLOv8 model...
# ================================================================================
#
# Model Information:
#   Model: Standard YOLOv8m
#   Input Size: 640
#   Pretrained: True
#   Customization: None (Baseline)
#   Confidence Threshold: 0.5
#   NMS IoU Threshold: 0.45
#
#   Total Parameters: ~25.9M
#
# ✓ Model initialized successfully

# %% [markdown]
# ## Cell 5: Step 3 - Train Model

# %%
# ============================================================================
# Step 3: Train Model
# ============================================================================

print("\n[3/5] Training model...")
print("=" * 80)

# Check for existing checkpoint
checkpoint_path = output_dir / 'train' / 'weights' / 'last.pt'
resume_training = False

if checkpoint_path.exists():
    print(f"\n✓ Found existing checkpoint: {checkpoint_path}")
    print("  Resuming training from last checkpoint...")

    try:
        import torch
        from ultralytics import YOLO

        checkpoint = torch.load(
            checkpoint_path,
            map_location='cpu',
            weights_only=False
        )

        last_epoch = checkpoint.get('epoch', 0)

        print(f"  Last completed epoch: {last_epoch + 1}")
        print(f"  Remaining epochs: {TRAINING_CONFIG_V1['epochs'] - (last_epoch + 1)}")

        # Load checkpoint model
        model.model = YOLO(str(checkpoint_path))

        resume_training = True

    except Exception as e:
        print(f"  Warning: Could not load checkpoint: {e}")
        print("  Starting fresh training instead...")
else:
    print(f"\n  No checkpoint found. Starting fresh training...")

# Initialize trainer
trainer = YOLOv8Trainer(**TRAINING_CONFIG_V1)

# Train model with resume option
training_results = trainer.train(
    model=model,
    train_data=DATASET_CONFIG,
    val_data=DATASET_CONFIG,
    output_dir=str(output_dir),
    resume=resume_training
)

# Print training summary
print("\n" + "=" * 80)
print("TRAINING COMPLETED")
print("=" * 80)
print(f"\nTraining Results:")
print(f"  Best mAP@0.5: {training_results.box.map50:.4f}")
print(f"  Best mAP@0.5:0.95: {training_results.box.map:.4f}")
print(f"  Output Directory: {output_dir}")
print("\n✓ Model training completed successfully")
# Out:
# [3/5] Training model...
# ================================================================================
#
# ✓ Found existing checkpoint: /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/train/weights/last.pt
#   Resuming training from last checkpoint...
#   Last completed epoch: 187
#   Remaining epochs: 113
#
# Training Configuration:
#   Learning Rate: 0.0005
#   Batch Size: 12
#   Epochs: 300
#   Optimizer: adam
#   Weight Decay: 0.0005
#   Mixed Precision: True
#   Early Stopping Patience: 30
#   Cosine LR: False
#   Close Mosaic: 0 epochs before end
#
# Ultralytics 8.4.48 🚀 Python-3.12.9 torch-2.6.0 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=12, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=0, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/sagemaker-user/CNN_A2/data/25509225/Object_Detection/yolo/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=300, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/train/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=adam, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1, rect=False, resume=/home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/train/weights/last.pt, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3778591  ultralytics.nn.modules.head.Detect           [5, 16, None, [192, 384, 576]]
# Model summary: 170 layers, 25,859,215 parameters, 25,859,199 gradients, 79.1 GFLOPs
#
# Transferred 475/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1928.4±562.0 MB/s, size: 57.4 KB)
# train: Scanning /home/sagemaker-user/CNN_A2/data/25509225/Object_Detection/yolo/train/labels.cache... 1167 images, 465 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1167/1167 212.8Mit/s 0.0s
# train: /home/sagemaker-user/CNN_A2/data/25509225/Object_Detection/yolo/train/images/100178.jpg: 1 duplicate labels removed
# train: /home/sagemaker-user/CNN_A2/data/25509225/Object_Detection/yolo/train/images/100179.jpg: 1 duplicate labels removed
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 991.3±367.7 MB/s, size: 58.2 KB)
# val: Scanning /home/sagemaker-user/CNN_A2/data/25509225/Object_Detection/yolo/valid/labels.cache... 250 images, 97 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 250/250 15.0Mit/s 0.0s
# val: /home/sagemaker-user/CNN_A2/data/25509225/Object_Detection/yolo/valid/images/101420.jpg: 1 duplicate labels removed
# val: /home/sagemaker-user/CNN_A2/data/25509225/Object_Detection/yolo/valid/images/101421.jpg: 1 duplicate labels removed
# optimizer: Adam(lr=0.0005, momentum=0.937) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.00046875), 83 bias(decay=0.0)
# Plotting labels to /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/train/labels.jpg...
# Resuming training /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/train/weights/last.pt from epoch 188 to 300 total epochs
# 2026/05/12 13:37:53 WARNING mlflow.utils.autologging_utils: MLflow statsmodels autologging is known to be compatible with 0.12.2 <= statsmodels <= 0.14.4, but the installed version is 0.14.6. If you encounter errors during autologging, try upgrading / downgrading statsmodels to a compatible version, or try upgrading MLflow.
# 2026/05/12 13:37:53 INFO mlflow.tracking.fluent: Autologging successfully enabled for statsmodels.
# MLflow: logging run_id(1ce20ecef3754350a487f6c7db36f146) to runs/mlflow
# MLflow: view at http://127.0.0.1:5000 with 'mlflow server --backend-store-uri runs/mlflow'
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/train
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     188/300      10.1G     0.5887     0.2901     0.8083        492        640: 100% ━━━━━━━━━━━━ 98/98 2.5it/s 38.5s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.2it/s 3.4s0.3s
#                    all        250      14743      0.974      0.965      0.989      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     189/300      7.48G     0.5921     0.2928     0.8104        283        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743       0.98      0.958      0.989      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     190/300      7.53G     0.5979     0.2933      0.809        321        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.978      0.962      0.989       0.84
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     191/300      8.31G     0.5894     0.2902     0.8102        618        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743       0.97       0.97       0.99      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     192/300      8.34G     0.5955     0.2924     0.8101        491        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.978      0.961      0.989      0.842
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     193/300      7.79G     0.5868     0.2879     0.8087         87        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.979      0.967      0.989      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     194/300      7.23G     0.5885     0.2888     0.8076        190        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.982      0.963       0.99      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     195/300      8.07G     0.5828     0.2903     0.8072        200        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.982      0.961      0.989      0.842
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     196/300       7.4G     0.5736     0.2864     0.8092         75        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743       0.98       0.96      0.989      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     197/300      7.76G     0.5756     0.2867     0.8085        121        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.979      0.956      0.989      0.842
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     198/300      7.69G     0.5591     0.2818      0.807        211        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.981      0.961      0.989      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     199/300      8.49G      0.568     0.2854     0.8091         50        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.3it/s 3.3s0.3s
#                    all        250      14743       0.97      0.967      0.989      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     200/300      8.38G     0.5789     0.2872     0.8073         28        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.984      0.958      0.989      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     201/300      8.39G     0.5787     0.2857     0.8097        428        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.3it/s 3.3s0.3s
#                    all        250      14743      0.979      0.965      0.989      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     202/300       7.2G     0.5607     0.2815     0.8061        100        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.972      0.966       0.99      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     219/300      7.41G     0.5322     0.2705      0.803        123        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.3it/s 3.3s0.3s
#                    all        250      14743      0.983      0.959      0.989      0.858
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     220/300      7.54G     0.5428     0.2747      0.803         86        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.983      0.959       0.99      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     221/300      8.19G     0.5335     0.2694     0.8035         42        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.983      0.964      0.991      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     222/300      7.81G     0.5332     0.2703     0.8016        140        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.982      0.968      0.991      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     223/300       8.2G     0.5333     0.2691     0.8035         72        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.976      0.968       0.99      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     224/300      7.94G     0.5343      0.269     0.8021        301        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.978      0.963       0.99      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     225/300      7.38G     0.5352     0.2675     0.8007        538        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.973       0.97       0.99      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     226/300      7.17G     0.5232     0.2628     0.8016        339        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.975       0.97       0.99      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     227/300      7.22G     0.5175     0.2619     0.8001        157        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.976      0.969       0.99      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     228/300      8.12G     0.5209     0.2625     0.8004        445        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.969      0.972       0.99      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     229/300      7.79G      0.516      0.261     0.8014        385        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.971      0.971       0.99      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     230/300      7.23G     0.5181     0.2645     0.8027         81        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743       0.98      0.963       0.99      0.861
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     246/300      7.01G     0.4944      0.253     0.7972        290        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.981      0.966      0.991      0.862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     247/300      7.05G     0.4977      0.254     0.7992        352        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.978       0.97      0.991      0.863
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     248/300      8.18G     0.4931     0.2526     0.7985        542        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.983      0.963       0.99      0.863
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     249/300      7.36G     0.4901     0.2526     0.7983         64        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.979      0.966       0.99      0.863
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     250/300      6.97G     0.4999     0.2543     0.7984        623        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.983      0.965      0.991      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     251/300      7.87G     0.4791     0.2468     0.7962        195        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.981      0.967      0.991      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     252/300      8.33G     0.4919     0.2517     0.7965        304        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.984      0.966      0.991      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     253/300      7.29G     0.4816       0.25     0.7973         65        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.983      0.964      0.991      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     254/300      7.32G     0.4796      0.247     0.7963        813        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.979      0.969      0.991      0.865
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     255/300      6.71G     0.4806     0.2485     0.7969        191        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.979      0.963       0.99      0.865
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     256/300      6.75G     0.4918     0.2518     0.7972        711        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.978      0.967      0.991      0.865
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     257/300      6.81G     0.4831     0.2482     0.7972         70        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.3it/s 3.3s0.3s
#                    all        250      14743       0.98      0.966       0.99      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     258/300      7.58G     0.4823     0.2456     0.7975        270        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.3it/s 3.3s0.3s
#                    all        250      14743      0.975      0.973      0.991      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     259/300      6.82G     0.4774     0.2441     0.7972        200        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.982      0.967      0.991      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     260/300      7.55G     0.4741     0.2445     0.7975        351        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.3it/s 3.3s0.3s
#                    all        250      14743      0.985      0.962      0.991      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     261/300       7.6G     0.4757     0.2468     0.7955        591        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.3it/s 3.3s0.3s
#                    all        250      14743      0.984      0.964      0.991      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     262/300      7.54G     0.4804     0.2464     0.7971        211        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.981      0.968      0.991      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     263/300      7.51G     0.4813     0.2453     0.7966        398        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.982      0.968      0.991       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     264/300         7G     0.4746     0.2445      0.795        219        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.981      0.966      0.991      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     265/300      7.03G     0.4647     0.2426     0.7954        141        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.979      0.969       0.99       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     281/300       7.4G     0.4429      0.233     0.7936        344        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.983      0.967      0.991      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     282/300      9.25G      0.445     0.2342     0.7919        233        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.983      0.968      0.991      0.875
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     283/300       7.2G     0.4432     0.2321     0.7936        240        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.985      0.966      0.991      0.874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     284/300      7.23G     0.4534     0.2346     0.7934        405        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.981      0.969      0.991      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     285/300       8.2G     0.4467     0.2337     0.7925        154        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.979       0.97      0.991      0.874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     286/300       7.1G     0.4474     0.2325     0.7937        504        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.979      0.971      0.991      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     287/300      7.14G     0.4415     0.2315     0.7945        290        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.4s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.986      0.965      0.991      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     288/300      7.16G     0.4461      0.233     0.7914         68        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.982      0.969      0.991      0.874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     289/300      8.02G      0.439     0.2295     0.7941        201        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.982      0.969      0.991      0.874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     290/300      7.45G     0.4354     0.2291     0.7934        333        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.979      0.971      0.991      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     291/300      6.63G     0.4337     0.2275     0.7929        210        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.983      0.967      0.991      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     292/300      8.47G     0.4362     0.2291      0.791        209        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.984      0.968      0.991      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     293/300      8.72G     0.4369      0.229     0.7926        167        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.983      0.969      0.992      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     294/300      9.07G     0.4334     0.2267     0.7914        358        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.983      0.969      0.991      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     295/300      7.53G     0.4338     0.2277     0.7935        490        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.983      0.968      0.991      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     296/300      7.87G     0.4399     0.2292     0.7921        327        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 37.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.2s0.3s
#                    all        250      14743      0.984      0.966      0.991      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     297/300      7.87G     0.4372      0.229     0.7928        545        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.3it/s 3.3s0.3s
#                    all        250      14743      0.986      0.966      0.991      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     298/300      8.04G     0.4334     0.2276     0.7934        184        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.3it/s 3.3s0.3s
#                    all        250      14743      0.986      0.966      0.991      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     299/300       6.9G      0.423     0.2244       0.79        136        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.3it/s 3.3s0.3s
#                    all        250      14743      0.986      0.966      0.991      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     300/300      8.63G     0.4278     0.2252     0.7909        109        640: 100% ━━━━━━━━━━━━ 98/98 2.6it/s 38.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.4it/s 3.3s0.3s
#                    all        250      14743      0.986      0.966      0.991      0.874
#
# 113 epochs completed in 1.348 hours.
# Optimizer stripped from /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/train/weights/last.pt, 52.1MB
# Optimizer stripped from /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/train/weights/best.pt, 52.1MB
#
# Validating /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/train/weights/best.pt...
# Ultralytics 8.4.48 🚀 Python-3.12.9 torch-2.6.0 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 93 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 1.3it/s 8.2s0.4s
#                    all        250      14743      0.983      0.968      0.991      0.874
#                   Cell        118        862      0.989      0.957      0.989      0.871
#             Cell-Multi         92        470       0.97      0.955      0.989      0.857
#             No-Anomaly        149      11322      0.992      0.995      0.994      0.877
#              Shadowing         43       1580       0.99      0.979      0.993      0.853
#           Unclassified         92        509      0.971      0.951      0.991      0.913
# Speed: 0.2ms preprocess, 7.6ms inference, 0.0ms loss, 2.8ms postprocess per image
# Results saved to /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/train
# MLflow: results logged to runs/mlflow
# MLflow: disable with 'yolo settings mlflow=False'
#
# ================================================================================
# TRAINING COMPLETED
# ================================================================================
#
# Training Results:
#   Best mAP@0.5: 0.9911
#   Best mAP@0.5:0.95: 0.8744
#   Output Directory: /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1
#
# ✓ Model training completed successfully

# %%
# ============================================================================
# Step 4: Evaluate on Test Set
# ============================================================================

print("\n[4/5] Evaluating on test set...")
print("=" * 80)

# Initialize evaluator
evaluator = DetectionEvaluator()

# Evaluate model
metrics = evaluator.evaluate_yolov8(
    model=model,
    test_dataset=DATASET_CONFIG,
    output_dir=str(output_dir)
)

print("\n" + "=" * 80)
print("EVALUATION COMPLETED")
print("=" * 80)
print(f"\nTest Set Metrics:")
print(f"  mAP@0.5: {metrics['map50']:.4f}")
print(f"  mAP@0.5:0.95: {metrics['map50_95']:.4f}")
print(f"  Precision: {metrics['precision']:.4f}")
print(f"  Recall: {metrics['recall']:.4f}")
print(f"  F1-Score: {metrics['f1']:.4f}")
print("\n✓ Model evaluation completed successfully")
# Out:
# [4/5] Evaluating on test set...
# ================================================================================
# ================================================================================
# MODEL EVALUATION
# ================================================================================
# WARNING ⚠️ 'save_hybrid' is deprecated and will be removed in the future.
# Ultralytics 8.4.48 🚀 Python-3.12.9 torch-2.6.0 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 93 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1636.2±522.0 MB/s, size: 57.5 KB)
# val: Scanning /home/sagemaker-user/CNN_A2/data/25509225/Object_Detection/yolo/test/labels.cache... 250 images, 79 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 250/250 95.3Mit/s 0.0s
# val: /home/sagemaker-user/CNN_A2/data/25509225/Object_Detection/yolo/test/images/101422.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.8it/s 9.1s0.4s
#                    all        250      14860      0.983      0.975      0.992      0.881
#                   Cell        126        819      0.973      0.963      0.989      0.879
#             Cell-Multi         95        450      0.967      0.958      0.991      0.872
#             No-Anomaly        168      11211      0.995      0.994      0.995      0.878
#              Shadowing         48       1890      0.991      0.985      0.993      0.855
#           Unclassified         92        490      0.988      0.976      0.992      0.921
# Speed: 1.4ms preprocess, 15.4ms inference, 0.2ms loss, 13.7ms postprocess per image
# Results saved to /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/evaluation/val
# ✓ Saved evaluation metadata to /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/evaluation
#
# === Test Set Metrics ===
# mAP@0.5: 0.9918
# mAP@0.5:0.95: 0.8809
# Precision: 0.9828
# Recall: 0.9751
# F1-Score: 0.0000
#
# ================================================================================
# EVALUATION COMPLETED
# ================================================================================
#
# Test Set Metrics:
#   mAP@0.5: 0.9918
#   mAP@0.5:0.95: 0.8809
#   Precision: 0.9828
#   Recall: 0.9751
#   F1-Score: 0.0000
#
# ✓ Model evaluation completed successfully

# %%
# ============================================================================
# Visualization 1: Detection Results Comparison (Labels vs Predictions)
# ============================================================================

print("\n=== Detection Results Comparison ===")
print("=" * 80)

# Display comparison images from evaluation results (no need to re-run inference)
fig = evaluator.plot_detection_comparison(output_dir=str(output_dir))
if fig is not None:
    print("\n✓ Detection comparison displayed")
    print("Left column: Ground truth labels")
    print("Right column: Model predictions")
else:
    print("Warning: Could not generate detection comparison")
    print("This may be because evaluation images were not saved.")
# Out:
# === Detection Results Comparison ===
# ================================================================================
# Found 3 comparison pairs, displaying Batch 0:
#   val_batch0_labels.jpg vs val_batch0_pred.jpg
# ✓ Detection comparison displayed
# Left column: Ground truth labels
# Right column: Model predictions

# %%
# ============================================================================
# Visualization 2: Training Loss Curves (Box Loss + Classification Loss)
# ============================================================================

print("\n=== Training Loss Curves ===")
print("=" * 80)

# Store training output path for visualization
train_output_dir = output_dir

# Plot training loss curves
fig = evaluator.plot_training_losses(str(train_output_dir))
if fig is not None:
    plt.show()
    print("\n✓ Training loss curves displayed")
else:
    print("Warning: Could not generate training loss curves")
    print("This may be because training results.csv is not available yet.")
    print("Try running the training cell (Cell 5) first if you haven't already.")
# Out:
# === Training Loss Curves ===
# ================================================================================
# ✓ Loaded training results from /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/train/results.csv
#   Shape: (300, 15)
#   Columns: ['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss', 'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss', 'lr/pg0', 'lr/pg1', 'lr/pg2']
# ✓ Training loss curves displayed

# %%
# ============================================================================
# Visualization 3: Validation mAP Curves (mAP@0.5 + mAP@0.5:0.95)
# ============================================================================

print("\n=== Validation mAP Curves ===")
print("=" * 80)

# Plot validation mAP curves
fig = evaluator.plot_validation_mAP(str(train_output_dir))
if fig is not None:
    plt.show()
    print("\n✓ Validation mAP curves displayed")
else:
    print("Warning: Could not generate validation mAP curves")
    print("This may be because training results.csv is not available yet.")
    print("Try running the training cell (Cell 5) first if you haven't already.")
# Out:
# === Validation mAP Curves ===
# ================================================================================
# ✓ Loaded training results from /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1/train/results.csv
#   Shape: (300, 15)
#   Columns: ['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss', 'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss', 'lr/pg0', 'lr/pg1', 'lr/pg2']
# ✓ Validation mAP curves displayed

# %%
# ============================================================================
# Visualization 4: Confusion Matrices (Unnormalized & Normalized)
# ============================================================================

print("\n=== Confusion Matrices ===")
print("=" * 80)

# Plot both confusion matrices side-by-side
fig = evaluator.plot_confusion_matrix(output_dir=str(train_output_dir))
if fig is not None:
    print("\n✓ Confusion matrices displayed")
else:
    print("Warning: Could not generate confusion matrices")
    print("This may be because the model training did not complete successfully.")
# Out:
# === Confusion Matrices ===
# ================================================================================
# ✓ Confusion matrices displayed

# %%
# ============================================================================
# Visualization 5: Precision-Recall Curves
# ============================================================================

print("\n=== Precision-Recall Curves ===")
print("=" * 80)

# Plot PR curves from training results (only BoxPR_curve.png)
fig = evaluator.plot_pr_curves_from_results(str(train_output_dir))
if fig is not None:
    print("\n✓ PR curves displayed")
else:
    print("Warning: Could not generate PR curves")
    print("This may be because BoxPR_curve.png was not generated during training.")
# Out:
# === Precision-Recall Curves ===
# ================================================================================
# ✓ PR curves displayed

# %%
# ============================================================================
# Analysis: Model Characteristics and Performance
# ============================================================================

print("\n" + "=" * 80)
print("MODEL ANALYSIS")
print("=" * 80)

# Model characteristics
total_params = sum(p.numel() for p in model.model.parameters())

print(f"\nModel Characteristics:")
print(f"  Backbone: YOLOv8{model_config['backbone']}")
print(f"  Input Size: {model_config['input_size']}")
print(f"  Total Parameters: ~{total_params/1e6:.1f}M")
print(f"  Customization: Baseline (no modifications)")
print(f"  Pretrained Weights: {USE_PRETRAINED}")

print(f"\nPerformance Summary:")
print(f"  Best mAP@0.5: {training_results.box.map50:.4f}")
print(f"  Best mAP@0.5:0.95: {training_results.box.map:.4f}")
print(f"  Test mAP@0.5: {metrics['map50']:.4f}")
print(f"  Test mAP@0.5:0.95: {metrics['map50_95']:.4f}")
print(f"  Test Precision: {metrics['precision']:.4f}")
print(f"  Test Recall: {metrics['recall']:.4f}")
print(f"  Test F1-Score: {metrics['f1']:.4f}")

print("\n" + "=" * 80)
print("BASELINE MODEL ANALYSIS")
print("=" * 80)
print("\nThis is the baseline model with no architectural modifications.")
print("It will be compared with:")
print("  - V2: YOLOv8m with Deeper Backbone (added convolutional layers)")
print("  - V3: YOLOv8m with Shallower Backbone (reduced convolutional layers)")
print("\n✓ Analysis completed")
# Out:
# ================================================================================
# MODEL ANALYSIS
# ================================================================================
#
# Model Characteristics:
#   Backbone: YOLOv8m
#   Input Size: 640
#   Total Parameters: ~25.8M
#   Customization: Baseline (no modifications)
#   Pretrained Weights: True
#
# Performance Summary:
#   Best mAP@0.5: 0.9911
#   Best mAP@0.5:0.95: 0.8744
#   Test mAP@0.5: 0.9918
#   Test mAP@0.5:0.95: 0.8809
#   Test Precision: 0.9828
#   Test Recall: 0.9751
#   Test F1-Score: 0.0000
#
# ================================================================================
# BASELINE MODEL ANALYSIS
# ================================================================================
#
# This is the baseline model with no architectural modifications.
# It will be compared with:
#   - V2: YOLOv8m with Deeper Backbone (added convolutional layers)
#   - V3: YOLOv8m with Shallower Backbone (reduced convolutional layers)
#
# ✓ Analysis completed

# %%
# ============================================================================
# Visualization 6: Training Results Summary (Comprehensive)
# ============================================================================

print("\n=== Training Results Summary ===")
print("=" * 80)

# Plot comprehensive training results (results.png with all metrics)
fig = evaluator.plot_training_results_summary(str(train_output_dir))
if fig is not None:
    print("\n✓ Training results summary displayed")
    print("This figure includes:")
    print("  - Box Loss and Classification Loss curves")
    print("  - mAP@0.5 and mAP@0.5:0.95 curves")
    print("  - Precision and Recall curves")
else:
    print("Warning: Could not generate training results summary")
    print("This may be because results.png was not generated during training.")
# Out:
# === Training Results Summary ===
# ================================================================================
# ✓ Training results summary displayed
# This figure includes:
#   - Box Loss and Classification Loss curves
#   - mAP@0.5 and mAP@0.5:0.95 curves
#   - Precision and Recall curves

# %%
# ============================================================================
# Final Summary
# ============================================================================

print("\n" + "=" * 80)
print("EXPERIMENT COMPLETED")
print("=" * 80)

print(f"\nExperiment: V1 - YOLOv8 Baseline")
print(f"Model: YOLOv8{model_config['backbone']} (Standard)")
print(f"Pretrained: {USE_PRETRAINED}")
print(f"Customization: None (Baseline)")

print(f"\n" + "-" * 80)
print(f"Training Performance:")
print(f"  Best mAP@0.5: {training_results.box.map50:.4f}")
print(f"  Best mAP@0.5:0.95: {training_results.box.map:.4f}")

print(f"\n" + "-" * 80)
print(f"Test Set Performance:")
print(f"  mAP@0.5: {metrics['map50']:.4f}")
print(f"  mAP@0.5:0.95: {metrics['map50_95']:.4f}")
print(f"  Precision: {metrics['precision']:.4f}")
print(f"  Recall: {metrics['recall']:.4f}")
print(f"  F1-Score: {metrics['f1']:.4f}")

print(f"\n" + "-" * 80)
print(f"Output Directory: {output_dir}")
print("\n" + "=" * 80)
print("✓ All experiments completed successfully")
print("=" * 80)
# Out:
# ================================================================================
# EXPERIMENT COMPLETED
# ================================================================================
#
# Experiment: V1 - YOLOv8 Baseline
# Model: YOLOv8m (Standard)
# Pretrained: True
# Customization: None (Baseline)
#
# --------------------------------------------------------------------------------
# Training Performance:
#   Best mAP@0.5: 0.9911
#   Best mAP@0.5:0.95: 0.8744
#
# --------------------------------------------------------------------------------
# Test Set Performance:
#   mAP@0.5: 0.9918
#   mAP@0.5:0.95: 0.8809
#   Precision: 0.9828
#   Recall: 0.9751
#   F1-Score: 0.0000
#
# --------------------------------------------------------------------------------
# Output Directory: /home/sagemaker-user/CNN_A2/notebooks/detection_YOLOv8/outputs/detection_yolov8_v1
#
# ================================================================================
# ✓ All experiments completed successfully
# ================================================================================
